# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks
from helpers import *

np.random.seed(42)
tf.random.set_seed(42)

# %%
DATASET_DIR = "../planetsdataset"

# %%
IMG_SIZE = (64, 64)
BATCH_SIZE = 32

# %%
train_dataset, valid_dataset, test_dataset, class_names = load_datasets(DATASET_DIR, IMG_SIZE, BATCH_SIZE)
num_classes = len(class_names)
# Out:
# Found 2430 files belonging to 12 classes.
# Found 666 files belonging to 12 classes.
# Found 341 files belonging to 12 classes.

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
valid_dataset = valid_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# %%
model = models.Sequential([
    layers.Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3)),
    layers.Rescaling(1.0 / 255),

    layers.Conv2D(16, (3, 3), activation="relu", padding="same"),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(32, (3, 3), activation="relu", padding="same"),
    layers.MaxPooling2D((2, 2)),

    layers.Flatten(),
    layers.Dense(64, activation="relu"),
    layers.Dense(num_classes, activation="softmax")
])

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
early_stopping = callbacks.EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True
)

# %%
history = model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=20,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/20
# 54/76 [====================>.........] - ETA: 3s - loss: 1.4747 - accuracy: 0.5515
# 2026-04-12 14:50:21.168498: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: known incorrect sRGB profile
# 76/76 [==============================] - 12s 138ms/step - loss: 1.3098 - accuracy: 0.6016 - val_loss: 0.7760 - val_accuracy: 0.7793
# Epoch 2/20
# 55/76 [====================>.........] - ETA: 2s - loss: 0.5740 - accuracy: 0.8313
# 2026-04-12 14:50:32.263642: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: known incorrect sRGB profile
# 76/76 [==============================] - 11s 130ms/step - loss: 0.5508 - accuracy: 0.8379 - val_loss: 0.5900 - val_accuracy: 0.8228
# Epoch 3/20
# 55/76 [====================>.........] - ETA: 2s - loss: 0.3975 - accuracy: 0.8864
# 2026-04-12 14:50:42.745478: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: known incorrect sRGB profile
# 76/76 [==============================] - 11s 126ms/step - loss: 0.3872 - accuracy: 0.8893 - val_loss: 0.5134 - val_accuracy: 0.8529
# Epoch 4/20
# 55/76 [====================>.........] - ETA: 2s - loss: 0.3387 - accuracy: 0.8960
# 2026-04-12 14:50:53.623073: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: known incorrect sRGB profile
# 76/76 [==============================] - 11s 129ms/step - loss: 0.3345 - accuracy: 0.9025 - val_loss: 0.5376 - val_accuracy: 0.8483
# Epoch 5/20
# 55/76 [====================>.........] - ETA: 2s - loss: 0.2256 - accuracy: 0.9352
# 2026-04-12 14:51:03.742633: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: known incorrect sRGB profile
# 76/76 [==============================] - 10s 122ms/step - loss: 0.2343 - accuracy: 0.9325 - val_loss: 0.4971 - val_accuracy: 0.8408
# Epoch 6/20
# 54/76 [====================>.........] - ETA: 2s - loss: 0.1697 - accuracy: 0.9554
# 2026-04-12 14:51:14.117149: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: known incorrect sRGB profile
# 76/76 [==============================] - 10s 122ms/step - loss: 0.1704 - accuracy: 0.9535 - val_loss: 0.4507 - val_accuracy: 0.8844
# Epoch 7/20
# 55/76 [====================>.........] - ETA: 2s - loss: 0.1258 - accuracy: 0.9670
# 2026-04-12 14:51:24.107948: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: known incorrect sRGB profile
# 76/76 [==============================] - 10s 120ms/step - loss: 0.1319 - accuracy: 0.9658 - val_loss: 0.4428 - val_accuracy: 0.8814
# Epoch 8/20
# 55/76 [====================>.........] - ETA: 2s - loss: 0.0991 - accuracy: 0.9761
# 2026-04-12 14:51:34.620609: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: known incorrect sRGB profile
# 76/76 [==============================] - 10s 122ms/step - loss: 0.0977 - accuracy: 0.9745 - val_loss: 0.5612 - val_accuracy: 0.8664
# Epoch 9/20
# 55/76 [====================>.........] - ETA: 2s - loss: 0.0899 - accuracy: 0.9778
# 2026-04-12 14:51:44.556460: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: known incorrect sRGB profile
# 76/76 [==============================] - 10s 119ms/step - loss: 0.0904 - accuracy: 0.9786 - val_loss: 0.4439 - val_accuracy: 0.9009
# Epoch 10/20
# 55/76 [====================>.........] - ETA: 2s - loss: 0.0621 - accuracy: 0.9824
# 2026-04-12 14:51:54.398121: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: known incorrect sRGB profile
# 76/76 [==============================] - 10s 117ms/step - loss: 0.0663 - accuracy: 0.9819 - val_loss: 0.4668 - val_accuracy: 0.8889
# Epoch 11/20
# 55/76 [====================>.........] - ETA: 2s - loss: 0.0537 - accuracy: 0.9864
# 2026-04-12 14:52:04.111071: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: known incorrect sRGB profile
# 76/76 [==============================] - 10s 116ms/step - loss: 0.0696 - accuracy: 0.9811 - val_loss: 0.5073 - val_accuracy: 0.8904
# Epoch 12/20
# 55/76 [====================>.........] - ETA: 2s - loss: 0.0621 - accuracy: 0.9847
# 2026-04-12 14:52:13.798970: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: known incorrect sRGB profile
# 76/76 [==============================] - 10s 116ms/step - loss: 0.0550 - accuracy: 0.9881 - val_loss: 0.4820 - val_accuracy: 0.8994

# %%
test_loss, test_acc = model.evaluate(test_dataset)
print("Test loss:", test_loss)
print("Test accuracy:", test_acc)
# Out:
# 11/11 [==============================] - 1s 25ms/step - loss: 0.3442 - accuracy: 0.8915
# Test loss: 0.34420982003211975
# Test accuracy: 0.8914955854415894
